# %% [markdown]
# <a href="https://colab.research.google.com/github/pujitharanigelam/html/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

data=pd.DataFrame({'x':[1,2,3,4,5],'y':[2,4,6,8,10]})

model=LinearRegression()
model.fit(data[['x']],data['y'])

print(model.coef_,model.intercept_)
# Out:
# [2.] 0.0

# %%
import matplotlib.pyplot as plt
plt.scatter(data['x'],data['y'])
plt.plot(data['x'],model.predict(data[['x']]),color='red')
plt.show()
